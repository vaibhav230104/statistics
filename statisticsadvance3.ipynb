# %%
#Q1 Estimate: It is an observed numerical value used to estimate the unknown population parameter.
# Point Estimate: Single numerical value used to estimate the unknown population parameter. Sample mean is a point estimate of a population mean.
# Interval Estimate: Range of values used to estimate the unknown population parameter.

# %%
#Q2
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    import math

    standard_error = sample_std_dev / math.sqrt(sample_size)
    margin_of_error = 1.96 * standard_error  # Assuming a 95% confidence interval

    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound
sample_mean = 50
sample_std_dev = 5
sample_size = 100

lower_bound, upper_bound = estimate_population_mean(sample_mean, sample_std_dev, sample_size)

print(f"Estimated population mean: {sample_mean} +/- {upper_bound - sample_mean} (95% confidence interval)")
# Out:
# Estimated population mean: 50 +/- 0.9799999999999969 (95% confidence interval)

# %%
#Q3 It is a statistical inference used to draw the conclusion about population based on sample data. It is used for scientific research, decision making, drawing conclusion.

# %%
#Q4
# Null Hypothesis (H0): The average weight of male college students is equal to the average weight of female college students.

# Alternative Hypothesis (H1): The average weight of male college students is greater than the average weight of female college students.

# %%
#Q5
import numpy as np
import scipy.stats as stat
sample1 = [67, 71, 62, 75, 68]
sample2 = [61, 64, 70, 58, 66]
alpha = 0.05
df1 = len(sample1)-1
df2 = len(sample2)-1

f_test = np.var(sample1,ddof=1)/np.var(sample2,ddof=1)
critical_value=stat.f.ppf(q=1-alpha,dfn=df1,dfd=df2)

if f_test>critical_value:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We fail to reject the null hypothesis

# %%
#Q6 Example: A milk factory says a packet of milk contain 5 lt of milk, a worker who works in this factory says a packet contain less than 5 lt of milk.
# Null Hypothesis(H0): milk contain 5 lt
# Alternate Hypotheis(H1): milk contain less than 5 lt.

# %%
#Q7 a. First right down H0 and H1.
# b. After that the test which suits perfect apply that test

# %%
#Q8. In hypothesis testing, the p-value is a statistical measure that quantifies the strength of evidence against the null hypothesis. It represents the probability of obtaining the observed sample data, or more extreme data, assuming that the null hypothesis is true.
#Significance Of Hypothesis Testing: Comparison, Decison Making.

# %%
#Q9
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Set the degrees of freedom
df = 10

# Generate x values for the plot
x = np.linspace(-4, 4, 1000)

# Calculate the probability density function (pdf) for the Student's t-distribution
pdf = stats.t.pdf(x, df)

# Create the plot
plt.plot(x, pdf, label=f"t-distribution (df={df})")
plt.title("Student's t-distribution")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.legend()

# Display the plot
plt.show()

# %%
#Q13 
n=50
x=500
std_dev= 50
alpha = 0.05
z = stats.norm.ppf(q= 1-0.025)     # 0.95+0.025
lower = x-z*std_dev/(50)**0.5
upper = x+z*std_dev/(50)**0.5
print((lower,upper))
# Out:
# (486.1409617565032, 513.8590382434968)

# %%
#Q14
#H0 = new drug will not drecrease the blood pressure by 10 mgHg 
#H1 = new drug will decrease the blood pressure by 10 mgHg
n = 100
x = 8
std_dev = 3
z0 = stats.norm.ppf(0.05)
z = (x - 10)*(n**0.5)/std_dev
if z<z0:
    print('We reject null hypothesis')
else :
    print('We fail to reject null hypothesis')
# Out:
# We reject null hypothesis

# %%
#Q15
#H0 = the true mean weight of the products is equal to 5
#H1 = the true mean weight of the products is less than 5
n = 25
std_dev = 0.5
x = 4.8
t = (x - 5)*(n**0.5)/std_dev
t0 = stats.t.ppf(0.01,df=24)
if t<t0:
    print('We reject null hypothesis')
else:
    print('We fail to reject null hypothesis')
# Out:
# We fail to reject null hypothesis

# %%
#Q16
# Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.
n1 = 30
x1 = 80
std_dev1 = 10
n2 = 40
x2 = 75
std_dev2 = 8
alpha = 0.01

F_test = (10/8)**2

critical_value = stats.f.ppf(q=1-alpha,dfn=n1-1,dfd=n2-1)
if F_test>critical_value:
    print("We reject null hypothesis")
else:
    print("We fail to reject the null hypothesis")
# Out:
# We fail to reject the null hypothesis

# %%
#Q17
n = 50
std_dev = 1.5
x = 4
z = stats.norm.ppf(q=0.995 )     # 0.99+0.005
lower = x-z*std_dev/(50)**0.5
upper = x+z*std_dev/(50)**0.5
print((lower,upper))
# Out:
# (3.4535840896844654, 4.546415910315535)
